# %%
from pandas import read_csv

# %%
pwd
# Out:
# '/home/loic/repos/mexico/sandbox'

# %%
df = read_csv('../pipeline.in.v2/PEF_AC01_2t_2016.csv', encoding='windows-1252')

# %%
df.sample(n=50)
# Out:
#        Ciclo  Ramo                                Descripción de Ramo  \
# 78136   2016     7                                   Defensa Nacional
# 83537   2016     9                       Comunicaciones y Transportes
# 39788   2016     3                                     Poder Judicial
# 70135   2016    51  Instituto de Seguridad y Servicios Sociales de...
# 57546   2016    50               Instituto Mexicano del Seguro Social
# 54740   2016    50               Instituto Mexicano del Seguro Social
# 70157   2016    51  Instituto de Seguridad y Servicios Sociales de...
# 28027   2016    20                                  Desarrollo Social
# 53930   2016    50               Instituto Mexicano del Seguro Social
# 38733   2016    23                Provisiones Salariales y Económicas
# 25660   2016    18                                            Energía
# 4617    2016    11                                  Educación Pública
# ...

# %%
df.columns
# Out:
# Index(['Ciclo', 'Ramo', 'Descripción de Ramo', 'Unidad Responsable',
#        'Descripción de Unidad Responsable', 'Grupo Funcional',
#        'Descripción de Grupo Funcional', 'Función', 'Descripción de Función',
#        'Subfunción', 'Descripción de Subfunción', 'Actividad Institucional',
#        'Descripción de la Actividad Institucional',
#        'Modalidad del Programa presupuestario',
#        'Descripción de la modalidad del programa presupuestario',
#        'Programa Presupuestario', 'Descripción de Programa Presupuestario',
#        'ID_CAPITULO', 'DESC_CAPITULO', 'ID_CONCEPTO', 'DESC_CONCEPTO',
#        'Tipo de Gasto', 'Descripción de Tipo de Gasto',
#        'Fuente de Financiamiento', 'Descripción de Fuente de Financiamiento',
#        'Entidad Federativa', 'Descripción de la entidad federativa',
#        'Clave de cartera', 'Aprobado', 'Ejercido', 'Pagado'],
#       dtype='object')

# %%
from json import loads, dumps

with open('/home/loic/repos/mexico/pipeline.out/iteration-14-all-new-data-2008-2016/datapackage.fiscal.json') as file:
    d = loads(file.read())
    with open('/home/loic/repos/mexico/pipeline.out/iteration-14-all-new-data-2008-2016/datapackage.json', 'w+', encoding='utf-8') as out:
        out.write(dumps(d, ensure_ascii=True, indent=4))

# %%
from cchardet import detect

# %%
with open('/home/loic/repos/mexico/pipeline.out/iteration-14-all-new-data-2008-2016/datapackage.json', 'rb') as f:
    yo = detect(f.read())
yo
# Out:
# {'confidence': 0.9900000095367432, 'encoding': 'UTF-8'}

# %%
from pandas import
