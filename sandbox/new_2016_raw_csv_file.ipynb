# %%
from pandas import read_csv

budget = read_csv('pipeline.in/2016_2T_Gasto_OS.csv', encoding='cp850')
# Out:
# /usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py:2705: DtypeWarning: Columns (5,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
budget.columns
# Out:
# Index(['Actividad Institucional', 'Adefas', 'Aprobado', 'Capitulo', 'Ciclo',
#        'Clave de cartera', 'Concepto', 'Descripci¾n de Capitulo',
#        'Descripci¾n de Concepto', 'Descripci¾n de Fuente de Financiamiento',
#        'Descripci¾n de Funci¾n', 'Descripci¾n de Grupo Funcional',
#        'Descripcion de Partida EspecÝfica', 'Descripci¾n de Partida GenÚrica',
#        'Descripci¾n de Programa Presupuestario', 'Descripci¾n de Ramo',
#        'Descripci¾n de subfunci¾n', 'Descripci¾n de Tipo de Gasto',
#        'Descripci¾n de Unidad Responsable',
#        'Descripci¾n de Actividad Institucional',
#        'Descripci¾n de Entidad Federativa',
#        'Descripci¾n de la modalidad del programa presupuestario', 'Devengado',
#        'Ejercicio', 'Ejercido', 'Entidad Federativa',
#        'Fuente de Finaciamiento', 'Funci¾n', 'Grupo Funcional',
#        'Modalidad del Programa presupuestario', 'Modificado', 'Pagado',
# ...

# %%
import cchardet

with open('pipeline.in/2016_2T_Gasto_OS.csv', 'rb') as f:
    text = f.read()
            
cchardet.detect(text)
# Out:
# {'confidence': 0.9900000095367432, 'encoding': 'WINDOWS-1252'}

# %%
budget = read_csv('pipeline.in/2016_2T_Gasto_OS.csv', encoding='windows-1252')
# Out:
# /usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py:2705: DtypeWarning: Columns (5,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
budget.columns
# Out:
# Index(['Actividad Institucional', 'Adefas', 'Aprobado', 'Capitulo', 'Ciclo',
#        'Clave de cartera', 'Concepto', 'Descripción de Capitulo',
#        'Descripción de Concepto', 'Descripción de Fuente de Financiamiento',
#        'Descripción de Función', 'Descripción de Grupo Funcional',
#        'Descripcion de Partida Específica', 'Descripción de Partida Genérica',
#        'Descripción de Programa Presupuestario', 'Descripción de Ramo',
#        'Descripción de subfunción', 'Descripción de Tipo de Gasto',
#        'Descripción de Unidad Responsable',
#        'Descripción de Actividad Institucional',
#        'Descripción de Entidad Federativa',
#        'Descripción de la modalidad del programa presupuestario', 'Devengado',
#        'Ejercicio', 'Ejercido', 'Entidad Federativa',
#        'Fuente de Finaciamiento', 'Función', 'Grupo Funcional',
#        'Modalidad del Programa presupuestario', 'Modificado', 'Pagado',
# ...

# %%
cat pipeline.in/2016_2T_Gasto_OS.csv | head -n 20
# Out:
# Actividad Institucional,Adefas,Aprobado,Capitulo,Ciclo,Clave de cartera,Concepto,Descripci�n de Capitulo,Descripci�n de Concepto,Descripci�n de Fuente de Financiamiento,Descripci�n de Funci�n,Descripci�n de Grupo Funcional,Descripcion de Partida Espec�fica,Descripci�n de Partida Gen�rica,Descripci�n de Programa Presupuestario,Descripci�n de Ramo,Descripci�n de subfunci�n,Descripci�n de Tipo de Gasto,Descripci�n de Unidad Responsable,Descripci�n de Actividad Institucional,Descripci�n de Entidad Federativa,Descripci�n de la modalidad del programa presupuestario,Devengado,Ejercicio,Ejercido,Entidad Federativa,Fuente de Finaciamiento,Funci�n,Grupo Funcional,Modalidad del Programa presupuestario,Modificado,Pagado,Partida Espec�fica,Partida Gen�rica,Programa Presupuestario,RAMO,Subfunci�n,Tipo de Gasto,Unidad Responsable
# ...

# %%
subset = ['Ciclo', 
          'Capitulo', 
          'Concepto', 
          'Partida Genérica',        
          'Partida Específica', 
          'Descripción de Capitulo',
          'Descripción de Concepto', 
          'Descripción de Partida Genérica',
          'Descripcion de Partida Específica']

budget[subset].sample(n=20)
# Out:
#         Ciclo  Capitulo  Concepto  Partida Genérica  Partida Específica  \
# 69400    2016      2000      2400               NaN                 NaN
# 85451    2016      2000      2100               NaN                 NaN
# 148703   2016      3000      3200               NaN                 NaN
# 5743     2016      1000      1300               NaN                 NaN
# 30007    2016      2000      2100               NaN                 NaN
# 62976    2016      2000      2200               NaN                 NaN
# 221633   2016      2000      2500               NaN                 NaN
# 129678   2016      3000      3500               NaN                 NaN
# 19992    2016      3000      3100               NaN                 NaN
# 140362   2016      3000      3300               NaN                 NaN
# 101334   2016      1000      1500               NaN                 NaN
# 209799   2016      1000      1500               NaN                 NaN
# ...

# %%
budget.head(n=20)
# Out:
#     Actividad Institucional  Adefas     Aprobado  Capitulo  Ciclo  \
# 0                         4     NaN   99305000.0      6000   2016
# 1                         4     NaN  632268000.0      1000   2016
# 2                         4     NaN  371670481.0      1000   2016
# 3                         4     NaN  940735863.0      1000   2016
# 4                         4     NaN   24461262.0      1000   2016
# 5                         4     NaN    4323000.0      1000   2016
# 6                         4     NaN  293298846.0      1000   2016
# 7                         4     NaN   44492174.0      1000   2016
# 8                         4     NaN    7800000.0      1000   2016
# 9                         4     NaN    4346669.0      1000   2016
# 10                        4     NaN  189630956.0      1000   2016
# 11                        4     NaN  480923055.0      1000   2016
# 12                        4     NaN   92472124.0      1000   2016
# ...
